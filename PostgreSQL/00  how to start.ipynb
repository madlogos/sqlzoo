# %% [markdown]
# # 在JupyterLab中运行SQL

# %% [markdown]
# 1. 需要用到[`ipython-sql`](https://github.com/catherinedevlin/ipython-sql/)包，安装方法：
#     ```bash
#     pip install ipython-sql
#     ```
# 1. 启动数据库`localhost/sqlzoo`（数据需提前导入）。
# 1. 通过`sqlalchemy`形式的DB URI连接sqlzoo数据库。
#
# 本案例使用PostgreSQL，也可以使用MySQL/MariaDB。
#
# > macOS Mojave无法安装`mysql-python`，只能装`pymysql`。因此如使用MySQL的话，URI要写成`mysql+pymysq://...`的形式。

# %%
import getpass
# %load_ext sql
pwd = getpass.getpass()
# %sql mysql+pymysql://root:$pwd@localhost:3306/sqlzoo
# %sql postgresql://postgres:$pwd@localhost/sqlzoo
# Out:
#  ·········
# 'Connected: postgres@sqlzoo'

# %% [markdown]
# 连接上以后还可以做一些设置，比如将长度显示行数的上限为10：

# %%
# %config SqlMagic.displaylimit = 10

# %% [markdown]
# 记得每次运行SQL语句时，前面都要加`%%sql` magic符。

# %% [markdown]
# ## 举例

# %%
# %%sql
# SELECT * FROM world
# Out:
#  * postgresql://postgres:***@localhost/sqlzoo
# 195 rows affected.
# [('Afghanistan', 'Asia', Decimal('652230'), Decimal('25500100'), Decimal('20364000000'), 'Kabul', '.af', '//upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Afghanistan.svg'),
#  ('Albania', 'Europe', Decimal('28748'), Decimal('2821977'), Decimal('12044000000'), 'Tirana', '.al', '//upload.wikimedia.org/wikipedia/commons/3/36/Flag_of_Albania.svg'),
#  ('Algeria', 'Africa', Decimal('2381741'), Decimal('38700000'), Decimal('207021000000'), 'Algiers', '.dz', '//upload.wikimedia.org/wikipedia/commons/7/77/Flag_of_Algeria.svg'),
#  ('Andorra', 'Europe', Decimal('468'), Decimal('76098'), Decimal('3222000000'), 'Andorra la Vella', '.ad', '//upload.wikimedia.org/wikipedia/commons/1/19/Flag_of_Andorra.svg'),
#  ('Angola', 'Africa', Decimal('1246700'), Decimal('19183590'), Decimal('116308000000'), 'Luanda', '.ao', '//upload.wikimedia.org/wikipedia/commons/9/9d/Flag_of_Angola.svg'),
#  ('Antigua and Barbuda', 'Caribbean', Decimal('442'), Decimal('86295'), Decimal('1176000000'), "St. John's", '.ag', '//upload.wikimedia.org/wikipedia/commons/8/89/Flag_of_Antigua_and_Barbuda.svg'),
#  ('Argentina', 'South America', Decimal('2780400'), Decimal('42669500'), Decimal('477028000000'), 'Buenos Aires', '.ar', '//upload.wikimedia.org/wikipedia/commons/1/1a/Flag_of_Argentina.svg'),
#  ('Armenia', 'Eurasia', Decimal('29743'), Decimal('3017400'), Decimal('9950000000'), 'Yerevan', '.am', '//upload.wikimedia.org/wikipedia/commons/2/2f/Flag_of_Armenia.svg'),
#  ('Australia', 'Oceania', Decimal('7692024'), Decimal('23545500'), Decimal('1564419000000'), 'Canberra', '.au', '//upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Australia.svg'),
#  ('Austria', 'Europe', Decimal('83871'), Decimal('8504850'), Decimal('394458000000'), 'Vienna', '.at', '//upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_Austria.svg'),
#  ('Azerbaijan', 'Asia', Decimal('86600'), Decimal('9477100'), Decimal('68727000000'), 'Baku', '.az', '//upload.wikimedia.org/wikipedia/commons/d/dd/Flag_of_Azerbaijan.svg'),
#  ('Bahamas', 'Caribbean', Decimal('13878'), Decimal('351461'), Decimal('8043000000'), 'Nassau', '.bs', '//upload.wikimedia.org/wikipedia/commons/9/93/Flag_of_the_Bahamas.svg'),
#  ('Bahrain', 'Asia', Decimal('765'), Decimal('1234571'), Decimal('30362000000'), 'Manama', '.bh', '//upload.wikimedia.org/wikipedia/commons/f/f9/Flag_of_Bahrain_1972.svg'),
#  ('Bangladesh', 'Asia', Decimal('147570'), Decimal('156557000'), Decimal('127195000000'), 'Dhaka', '.bd', '//upload.wikimedia.org/wikipedia/commons/f/f9/Flag_of_Bangladesh.svg'),
#  ('Barbados', 'Caribbean', Decimal('430'), Decimal('285000'), Decimal('4533000000'), 'Bridgetown', '.bb', '//upload.wikimedia.org/wikipedia/commons/e/ef/Flag_of_Barbados.svg'),
#  ('Belarus', 'Europe', Decimal('207600'), Decimal('9467000'), Decimal('63259000000'), 'Minsk', '.by', '//upload.wikimedia.org/wikipedia/commons/8/85/Flag_of_Belarus.svg'),
#  ('Belgium', 'Europe', Decimal('30528'), Decimal('11198638'), Decimal('483402000000'), 'City of Brussels', '.be', '//upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Belgium.svg'),
#  ('Belize', 'North America', Decimal('22966'), Decimal('349728'), Decimal('1554000000'), 'Belmopan', '.bz', '//upload.wikimedia.org/wikipedia/commons/e/e7/Flag_of_Belize.svg'),
#  ('Benin', 'Africa', Decimal('112622'), Decimal('9988068'), Decimal('7557000000'), 'Porto-Novo', '.bj', '//upload.wikimedia.org/wikipedia/commons/0/0a/Flag_of_Benin.svg'),
#  ('Bhutan', 'Asia', Decimal('38394'), Decimal('749090'), Decimal('1861000000'), 'Thimphu', '.bt', '//upload.wikimedia.org/wikipedia/commons/9/91/Flag_of_Bhutan.svg'),
#  ('Bolivia', 'South America', Decimal('1098581'), Decimal('10027254'), Decimal('27035000000'), 'Sucre', '.bo', '//upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Bolivia.svg'),
#  ('Bosnia and Herzegovina', 'Europe', Decimal('51209'), Decimal('3791622'), Decimal('17319000000'), 'Sarajevo', '.ba', '//upload.wikimedia.org/wikipedia/commons/b/bf/Flag_of_Bosnia_and_Herzegovina.svg'),
#  ('Botswana', 'Africa', Decimal('582000'), Decimal('2024904'), Decimal('14410000000'), 'Gaborone', '.bw', '//upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_Botswana.svg'),
#  ('Brazil', 'South America', Decimal('8515767'), Decimal('202794000'), Decimal('2254109000000'), 'Brasília', '.br', '//upload.wikimedia.org/wikipedia/commons/0/05/Flag_of_Brazil.svg'),
#  ('Brunei', 'Asia', Decimal('5765'), Decimal('393162'), Decimal('16954000000'), 'Bandar Seri Begawan', '.bn', '//upload.wikimedia.org/wikipedia/commons/9/9c/Flag_of_Brunei.svg'),
#  ('Bulgaria', 'Europe', Decimal('110879'), Decimal('7245677'), Decimal('50972000000'), 'Sofia', '.bg', '//upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Bulgaria.svg'),
#  ('Burkina Faso', 'Africa', Decimal('272967'), Decimal('17322796'), Decimal('10687000000'), 'Ouagadougou', '.bf', '//upload.wikimedia.org/wikipedia/commons/3/31/Flag_of_Burkina_Faso.svg'),
#  ('Burundi', 'Africa', Decimal('27834'), Decimal('9420248'), Decimal('2257000000'), 'Bujumbura', '.bi', '//upload.wikimedia.org/wikipedia/commons/5/50/Flag_of_Burundi.svg'),
#  ('Cambodia', 'Asia', Decimal('181035'), Decimal('15184116'), Decimal('14038000000'), 'Phnom Penh', '.kh', '//upload.wikimedia.org/wikipedia/commons/8/83/Flag_of_Cambodia.svg'),
#  ('Cameroon', 'Africa', Decimal('475442'), Decimal('20386799'), Decimal('26094000000'), 'Yaoundé', '.cm', '//upload.wikimedia.org/wikipedia/commons/4/4f/Flag_of_Cameroon.svg'),
#  ('Canada', 'North America', Decimal('9984670'), Decimal('35427524'), Decimal('1585000000000'), 'Ottowa', '.ca', '//upload.wikimedia.org/wikipedia/en/c/cf/Flag_of_Canada.svg'),
#  ('Cape Verde', 'Africa', Decimal('4033'), Decimal('491875'), Decimal('1903000000'), 'Praia', '.cv', '//upload.wikimedia.org/wikipedia/commons/3/38/Flag_of_Cape_Verde.svg'),
#  ('Central African Republic', 'Africa', Decimal('622984'), Decimal('4709000'), Decimal('2184000000'), 'Bangui', '.cf', '//upload.wikimedia.org/wikipedia/commons/6/6f/Flag_of_the_Central_African_Republic.svg'),
#  ('Chad', 'Africa', Decimal('1284000'), Decimal('13211000'), Decimal('10183000000'), "N'Djamena", '.td', '//upload.wikimedia.org/wikipedia/commons/4/4b/Flag_of_Chad.svg'),
#  ('Chile', 'South America', Decimal('756102'), Decimal('17773000'), Decimal('268314000000'), 'Santiago', '.cl', '//upload.wikimedia.org/wikipedia/commons/7/78/Flag_of_Chile.svg'),
#  ('China', 'Asia', Decimal('9596961'), Decimal('1365370000'), Decimal('8358400000000'), 'Beijing', '.cn', '//upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_the_People%27s_Republic_of_China.svg'),
#  ('Colombia', 'South America', Decimal('1141748'), Decimal('47662000'), Decimal('369813000000'), 'Bogotá', '.co', '//upload.wikimedia.org/wikipedia/commons/2/21/Flag_of_Colombia.svg'),
#  ('Comoros', 'Africa', Decimal('1862'), Decimal('743798'), Decimal('616000000'), 'Moroni', '.km', '//upload.wikimedia.org/wikipedia/commons/9/94/Flag_of_the_Comoros.svg'),
#  ('Congo, Democratic Republic of', 'Africa', Decimal('2345000'), Decimal('69360000'), None, 'Kinshasa', '.cd', '//upload.wikimedia.org/wikipedia/commons/6/6f/Flag_of_the_Democratic_Republic_of_the_Congo.svg'),
#  ('Congo, Republic of', 'Africa', Decimal('342000'), Decimal('4559000'), None, 'Brazzaville', '.cg', '//upload.wikimedia.org/wikipedia/commons/9/92/Flag_of_the_Republic_of_the_Congo.svg'),
#  ('Costa Rica', 'North America', Decimal('51100'), Decimal('4667096'), Decimal('45107000000'), 'San José', '.cr', '//upload.wikimedia.org/wikipedia/commons/f/f2/Flag_of_Costa_Rica.svg'),
#  ("Côte d'Ivoire", 'Africa', Decimal('322483'), Decimal('23919000'), Decimal('34506000000'), 'Yamoussoukro', '.ci', '//upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_C%C3%B4te_d%27Ivoire.svg'),
#  ('Croatia', 'Europe', Decimal('56594'), Decimal('4290612'), Decimal('56447000000'), 'Zagreb', '.hr', '//upload.wikimedia.org/wikipedia/commons/1/1b/Flag_of_Croatia.svg'),
#  ('Cuba', 'Caribbean', Decimal('109884'), Decimal('11167325'), Decimal('71017000000'), 'Havana', '.cu', '//upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Cuba.svg'),
#  ('Cyprus', 'Asia', Decimal('9251'), Decimal('865878'), Decimal('22768000000'), 'Nicosia', '.cy', '//upload.wikimedia.org/wikipedia/commons/d/d4/Flag_of_Cyprus.svg'),
#  ('Czech Republic', 'Europe', Decimal('78865'), Decimal('10517400'), Decimal('196446000000'), 'Prague', '.cz', '//upload.wikimedia.org/wikipedia/commons/c/cb/Flag_of_the_Czech_Republic.svg'),
#  ('Denmark', 'Europe', Decimal('43094'), Decimal('5634437'), Decimal('314889000000'), 'Copenhagen', '.dk', '//upload.wikimedia.org/wikipedia/commons/9/9c/Flag_of_Denmark.svg'),
#  ('Djibouti', 'Africa', Decimal('23200'), Decimal('886000'), Decimal('1361000000'), 'Djibouti', '.dj', '//upload.wikimedia.org/wikipedia/commons/3/34/Flag_of_Djibouti.svg'),
#  ('Dominica', 'Caribbean', Decimal('751'), Decimal('71293'), Decimal('499000000'), 'Roseau', '.dm', '//upload.wikimedia.org/wikipedia/commons/c/c4/Flag_of_Dominica.svg'),
#  ('Dominican Republic', 'Caribbean', Decimal('48671'), Decimal('9445281'), Decimal('58898000000'), 'Santo Domingo', '.do', '//upload.wikimedia.org/wikipedia/commons/9/9f/Flag_of_the_Dominican_Republic.svg'),
#  ('Ecuador', 'South America', Decimal('276841'), Decimal('15774200'), Decimal('87495000000'), 'Quito', '.ec', '//upload.wikimedia.org/wikipedia/commons/e/e8/Flag_of_Ecuador.svg'),
#  ('Egypt', 'Asia', Decimal('1002450'), Decimal('86736900'), Decimal('254671000000'), 'Cairo', '.eg', '//upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Egypt.svg'),
#  ('El Salvador', 'North America', Decimal('21041'), Decimal('6384000'), Decimal('23864000000'), 'San Salvador', '.sv', '//upload.wikimedia.org/wikipedia/commons/3/34/Flag_of_El_Salvador.svg'),
#  ('Equatorial Guinea', 'Africa', Decimal('28051'), Decimal('1622000'), Decimal('14491000000'), 'Malabo', '.gq', '//upload.wikimedia.org/wikipedia/commons/3/31/Flag_of_Equatorial_Guinea.svg'),
#  ('Eritrea', 'Africa', Decimal('117600'), Decimal('6536000'), Decimal('3108000000'), 'Asmara', '.er', '//upload.wikimedia.org/wikipedia/commons/2/29/Flag_of_Eritrea.svg'),
#  ('Estonia', 'Europe', Decimal('45227'), Decimal('1315819'), Decimal('22376000000'), 'Tallinn', '.ee', '//upload.wikimedia.org/wikipedia/commons/8/8f/Flag_of_Estonia.svg'),
#  ('Ethiopia', 'Africa', Decimal('1104300'), Decimal('87952991'), Decimal('41605000000'), 'Addis Ababa', '.et', '//upload.wikimedia.org/wikipedia/commons/7/71/Flag_of_Ethiopia.svg'),
#  ('Fiji', 'Oceania', Decimal('18272'), Decimal('858038'), Decimal('3999000000'), 'Suva', '.fj', '//upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_Fiji.svg'),
#  ('Finland', 'Europe', Decimal('338424'), Decimal('5458038'), Decimal('247389000000'), 'Helsinki', '.fi', '//upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Finland.svg'),
#  ('France', 'Europe', Decimal('640679'), Decimal('65906000'), Decimal('2611221000000'), 'Paris', '.fr', '//upload.wikimedia.org/wikipedia/commons/c/c3/Flag_of_France.svg'),
#  ('Gabon', 'Africa', Decimal('267668'), Decimal('1711000'), Decimal('24076000000'), 'Libreville', '.ga', '//upload.wikimedia.org/wikipedia/commons/0/04/Flag_of_Gabon.svg'),
#  ('Gambia', 'Africa', Decimal('11295'), Decimal('1882450'), None, 'Banjul', '.gm', '//upload.wikimedia.org/wikipedia/commons/7/77/Flag_of_The_Gambia.svg'),
#  ('Georgia', 'Asia', Decimal('69700'), Decimal('4490500'), Decimal('15830000000'), 'Tbilisi', '.ge', '//upload.wikimedia.org/wikipedia/commons/0/0f/Flag_of_Georgia.svg'),
#  ('Germany', 'Europe', Decimal('357114'), Decimal('80716000'), Decimal('3425956000000'), 'Bonn', '.de', '//upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_Germany.svg'),
#  ('Ghana', 'Africa', Decimal('238533'), Decimal('27043093'), Decimal('40711000000'), 'Accra', '.gh', '//upload.wikimedia.org/wikipedia/commons/1/19/Flag_of_Ghana.svg'),
#  ('Greece', 'Europe', Decimal('131990'), Decimal('11123034'), Decimal('248941000000'), 'Athens', '.gr', '//upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Greece.svg'),
#  ('Grenada', 'Caribbean', Decimal('344'), Decimal('103328'), Decimal('783000000'), "St. George's", '.gd', '//upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Grenada.svg'),
#  ('Guatemala', 'North America', Decimal('108889'), Decimal('15806675'), Decimal('50377000000'), 'Guatemala City', '.gt', '//upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Guatemala.svg'),
#  ('Guinea', 'Africa', Decimal('245857'), Decimal('10824200'), Decimal('6092000000'), 'Conakry', '.gn', '//upload.wikimedia.org/wikipedia/commons/e/ed/Flag_of_Guinea.svg'),
#  ('Guinea-Bissau', 'Africa', Decimal('36125'), Decimal('1746000'), Decimal('849000000'), 'Bissau', '.gw', '//upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_Guinea-Bissau.svg'),
#  ('Guyana', 'South America', Decimal('214969'), Decimal('784894'), Decimal('2851000000'), 'Georgetown', '.gy', '//upload.wikimedia.org/wikipedia/commons/9/99/Flag_of_Guyana.svg'),
#  ('Haiti', 'Caribbean', Decimal('27750'), Decimal('10413211'), Decimal('7187000000'), 'Port-au-Prince', '.ht', '//upload.wikimedia.org/wikipedia/commons/5/58/Flag_of_Haiti_%281964-1986%29.svg'),
#  ('Honduras', 'North America', Decimal('112492'), Decimal('8555072'), Decimal('18564000000'), 'Tegucigalpa', '.hn', '//upload.wikimedia.org/wikipedia/commons/8/82/Flag_of_Honduras.svg'),
#  ('Hungary', 'Europe', Decimal('93028'), Decimal('9879000'), Decimal('124600000000'), 'Budapest', '.hu', '//upload.wikimedia.org/wikipedia/commons/c/c1/Flag_of_Hungary.svg'),
#  ('Iceland', 'Europe', Decimal('103000'), Decimal('326340'), Decimal('13579000000'), 'Reykjavík', '.is', '//upload.wikimedia.org/wikipedia/commons/c/ce/Flag_of_Iceland.svg'),
#  ('India', 'Asia', Decimal('3166414'), Decimal('1246160000'), Decimal('1875213000000'), 'New Delhi', '.in', '//upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_India.svg'),
#  ('Indonesia', 'Asia', Decimal('1904569'), Decimal('252164800'), Decimal('878043000000'), 'Jakarta', '.id', '//upload.wikimedia.org/wikipedia/commons/9/9f/Flag_of_Indonesia.svg'),
#  ('Iran', 'Asia', Decimal('1648195'), Decimal('77552000'), Decimal('551588000000'), 'Tehran', '.ir', '//upload.wikimedia.org/wikipedia/commons/c/ca/Flag_of_Iran.svg'),
#  ('Iraq', 'Asia', Decimal('438317'), Decimal('36004552'), Decimal('149370000000'), 'Baghdad', '.iq', '//upload.wikimedia.org/wikipedia/commons/f/f6/Flag_of_Iraq.svg'),
#  ('Ireland', 'Europe', Decimal('70273'), Decimal('4593100'), Decimal('210638000000'), 'Dublin', '.ie', '//upload.wikimedia.org/wikipedia/commons/4/45/Flag_of_Ireland.svg'),
#  ('Israel', 'Asia', Decimal('20770'), Decimal('8193900'), Decimal('241069000000'), 'Jerusalem', '.il', '//upload.wikimedia.org/wikipedia/commons/d/d4/Flag_of_Israel.svg'),
#  ('Italy', 'Europe', Decimal('301336'), Decimal('60782668'), Decimal('2013392000000'), 'Rome', '.it', '//upload.wikimedia.org/wikipedia/commons/0/03/Flag_of_Italy.svg'),
#  ('Jamaica', 'Caribbean', Decimal('10991'), Decimal('2717991'), Decimal('14795000000'), 'Kingston', '.jm', '//upload.wikimedia.org/wikipedia/commons/0/0a/Flag_of_Jamaica.svg'),
#  ('Japan', 'Asia', Decimal('377930'), Decimal('127090000'), Decimal('5960180000000'), 'Imperial Tokyo', '.jp', '//upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Japan.svg'),
#  ('Jordan', 'Asia', Decimal('89342'), Decimal('6602190'), Decimal('30937000000'), 'Amman', '.jo', '//upload.wikimedia.org/wikipedia/commons/c/c0/Flag_of_Jordan.svg'),
#  ('Kazakhstan', 'Europe', Decimal('2724900'), Decimal('17244000'), Decimal('202656000000'), 'Astana', '.kz', '//upload.wikimedia.org/wikipedia/commons/d/d3/Flag_of_Kazakhstan.svg'),
#  ('Kenya', 'Africa', Decimal('580367'), Decimal('45546000'), Decimal('40697000000'), 'Nairobi', '.ke', '//upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Kenya.svg'),
#  ('Kiribati', 'Oceania', Decimal('811'), Decimal('106461'), Decimal('176000000'), 'South Tarawa', '.ki', '//upload.wikimedia.org/wikipedia/commons/d/d3/Flag_of_Kiribati.svg'),
#  ('Kuwait', 'Asia', Decimal('17818'), Decimal('3065850'), Decimal('183219000000'), 'Kuwait City', '.kw', '//upload.wikimedia.org/wikipedia/commons/a/aa/Flag_of_Kuwait.svg'),
#  ('Kyrgyzstan', 'Asia', Decimal('199951'), Decimal('5776570'), Decimal('6475000000'), 'Bishkek', '.kg', '//upload.wikimedia.org/wikipedia/commons/c/c7/Flag_of_Kyrgyzstan.svg'),
#  ('Laos', 'Asia', Decimal('236800'), Decimal('6580800'), Decimal('9100000000'), 'Vientiane', '.la', '//upload.wikimedia.org/wikipedia/commons/5/56/Flag_of_Laos.svg'),
#  ('Latvia', 'Europe', Decimal('64559'), Decimal('1996500'), Decimal('28379000000'), 'Riga', '.lv', '//upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Latvia.svg'),
#  ('Lebanon', 'Asia', Decimal('10452'), Decimal('4966000'), Decimal('42490000000'), 'Beirut', '.lb', '//upload.wikimedia.org/wikipedia/commons/5/59/Flag_of_Lebanon.svg'),
#  ('Lesotho', 'Africa', Decimal('30355'), Decimal('2098000'), Decimal('2443000000'), 'Maseru', '.ls', '//upload.wikimedia.org/wikipedia/commons/c/c0/Flag_of_Lesotho_%281987-2006%29.svg'),
#  ('Liberia', 'Africa', Decimal('111369'), Decimal('4397000'), Decimal('1491000000'), 'Monrovia', '.lr', '//upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_Liberia.svg'),
#  ('Libya', 'Africa', Decimal('1759540'), Decimal('6253000'), Decimal('95802000000'), 'Tripoli', '.ly', '//upload.wikimedia.org/wikipedia/commons/0/05/Flag_of_Libya.svg'),
#  ('Liechtenstein', 'Europe', Decimal('160'), Decimal('37132'), Decimal('5827000000'), 'Vaduz', '.li', '//upload.wikimedia.org/wikipedia/commons/4/47/Flag_of_Liechtenstein.svg'),
#  ('Lithuania', 'Europe', Decimal('65300'), Decimal('2939431'), Decimal('42339000000'), 'Vilnius', '.lt', '//upload.wikimedia.org/wikipedia/commons/1/11/Flag_of_Lithuania.svg'),
#  ('Luxembourg', 'Europe', Decimal('2586'), Decimal('549700'), Decimal('55143000000'), 'Luxembourg', '.lu', '//upload.wikimedia.org/wikipedia/commons/d/da/Flag_of_Luxembourg.svg'),
#  ('Macedonia', 'Europe', Decimal('25713'), Decimal('2062294'), None, 'Skopje', '.mk', '//upload.wikimedia.org/wikipedia/commons/f/f8/Flag_of_Macedonia.svg'),
#  ('Madagascar', 'Africa', Decimal('587041'), Decimal('21263403'), Decimal('9968000000'), 'Antananarivo', '.mg', '//upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Madagascar.svg'),
#  ('Malawi', 'Africa', Decimal('118484'), Decimal('16829000'), Decimal('5653000000'), 'Lilongwe', '.mw', '//upload.wikimedia.org/wikipedia/commons/1/10/Flag_of_Malawi_%282010-2012%29.svg'),
#  ('Malaysia', 'Asia', Decimal('330803'), Decimal('30177000'), Decimal('304726000000'), 'Kuala Lumpur', '.my', '//upload.wikimedia.org/wikipedia/commons/6/66/Flag_of_Malaysia.svg'),
#  ('Maldives', 'Asia', Decimal('300'), Decimal('317280'), Decimal('2606000000'), 'Malé', '.mv', '//upload.wikimedia.org/wikipedia/commons/0/0f/Flag_of_Maldives.svg'),
#  ('Mali', 'Africa', Decimal('1240192'), Decimal('15768000'), Decimal('10262000000'), 'Bamako', '.ml', '//upload.wikimedia.org/wikipedia/commons/9/92/Flag_of_Mali.svg'),
#  ('Malta', 'Europe', Decimal('316'), Decimal('416055'), Decimal('8775000000'), 'Valletta', '.mt', '//upload.wikimedia.org/wikipedia/commons/7/73/Flag_of_Malta.svg'),
#  ('Marshall Islands', 'Oceania', Decimal('181'), Decimal('56086'), Decimal('198000000'), 'Majuro', '.mh', '//upload.wikimedia.org/wikipedia/commons/2/2e/Flag_of_the_Marshall_Islands.svg'),
#  ('Mauritania', 'Africa', Decimal('1030700'), Decimal('3461041'), Decimal('3866000000'), 'Nouakchott', '.mr', '//upload.wikimedia.org/wikipedia/commons/4/43/Flag_of_Mauritania.svg'),
#  ('Mauritius', 'Africa', Decimal('2040'), Decimal('1257900'), Decimal('11452000000'), 'Port Louis', '.mu', '//upload.wikimedia.org/wikipedia/commons/7/77/Flag_of_Mauritius.svg'),
#  ('Mexico', 'North America', Decimal('1964375'), Decimal('119713203'), Decimal('1183655000000'), 'Mexico City', '.mx', '//upload.wikimedia.org/wikipedia/commons/f/fc/Flag_of_Mexico.svg'),
#  ('Micronesia, Federated States of', 'Oceania', Decimal('702'), Decimal('101351'), Decimal('327000000'), 'Palikir', '.fm', '//upload.wikimedia.org/wikipedia/commons/e/e4/Flag_of_the_Federated_States_of_Micronesia.svg'),
#  ('Moldova', 'Europe', Decimal('33846'), Decimal('3557600'), Decimal('7253000000'), 'Chișinău', '.md', '//upload.wikimedia.org/wikipedia/commons/2/27/Flag_of_Moldova.svg'),
#  ('Monaco', 'Europe', Decimal('2'), Decimal('36950'), Decimal('5707000000'), 'Monaco-Ville', '.mc', '//upload.wikimedia.org/wikipedia/commons/e/ea/Flag_of_Monaco.svg'),
#  ('Mongolia', 'Asia', Decimal('1564110'), Decimal('2931300'), Decimal('10271000000'), 'Ulaanbaatar', '.mn', '//upload.wikimedia.org/wikipedia/commons/4/4c/Flag_of_Mongolia.svg'),
#  ('Montenegro', 'Europe', Decimal('13812'), Decimal('620029'), Decimal('4046000000'), 'Podgorica', '.me', '//upload.wikimedia.org/wikipedia/commons/6/64/Flag_of_Montenegro.svg'),
#  ('Morocco', 'Africa', Decimal('446550'), Decimal('33307500'), Decimal('95992000000'), 'Rabat', '.ma', '//upload.wikimedia.org/wikipedia/commons/2/2c/Flag_of_Morocco.svg'),
#  ('Mozambique', 'Africa', Decimal('801590'), Decimal('23700715'), Decimal('14605000000'), 'Maputo', '.mz', '//upload.wikimedia.org/wikipedia/commons/d/d0/Flag_of_Mozambique.svg'),
#  ('Myanmar', 'Asia', Decimal('676578'), Decimal('61120000'), Decimal('59444000000'), 'Naypyidaw', '.mm', '//upload.wikimedia.org/wikipedia/commons/8/8c/Flag_of_Myanmar.svg'),
#  ('Namibia', 'Africa', Decimal('825615'), Decimal('2113077'), Decimal('12807000000'), 'Windhoek', '.na', '//upload.wikimedia.org/wikipedia/commons/0/00/Flag_of_Namibia.svg'),
#  ('Nauru', 'Oceania', Decimal('21'), Decimal('9945'), Decimal('121000000'), 'Yaren District', '.nr', '//upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Nauru.svg'),
#  ('Nepal', 'Asia', Decimal('147181'), Decimal('26494504'), Decimal('18029000000'), 'Kathmandu', '.np', '//upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Nepal.svg'),
#  ('Netherlands', 'Europe', Decimal('41543'), Decimal('16857500'), Decimal('800535000000'), 'Amsterdam', '.nl', '//upload.wikimedia.org/wikipedia/commons/2/20/Flag_of_the_Netherlands.svg'),
#  ('New Zealand', 'Oceania', Decimal('270467'), Decimal('4538520'), Decimal('171256000000'), 'Wellington', '.nz', '//upload.wikimedia.org/wikipedia/commons/3/3e/Flag_of_New_Zealand.svg'),
#  ('Nicaragua', 'North America', Decimal('130373'), Decimal('6071045'), Decimal('10508000000'), 'Managua', '.ni', '//upload.wikimedia.org/wikipedia/commons/1/19/Flag_of_Nicaragua.svg'),
#  ('Niger', 'Africa', Decimal('1267000'), Decimal('17138707'), Decimal('6773000000'), 'Niamey', '.ne', '//upload.wikimedia.org/wikipedia/commons/f/f4/Flag_of_Niger.svg'),
#  ('Nigeria', 'Africa', Decimal('923768'), Decimal('178517000'), Decimal('286470000000'), 'Abuja', '.ng', '//upload.wikimedia.org/wikipedia/commons/7/79/Flag_of_Nigeria.svg'),
#  ('North Korea', 'Asia', Decimal('120538'), Decimal('25027000'), Decimal('14411000000'), 'Pyongyang', '.kp', '//upload.wikimedia.org/wikipedia/commons/5/51/Flag_of_North_Korea.svg'),
#  ('Norway', 'Europe', Decimal('323802'), Decimal('5124383'), Decimal('499667000000'), 'Oslo', '.no', '//upload.wikimedia.org/wikipedia/commons/d/d9/Flag_of_Norway.svg'),
#  ('Oman', 'Asia', Decimal('309500'), Decimal('4020000'), Decimal('78111000000'), 'Muscat', '.om', '//upload.wikimedia.org/wikipedia/commons/d/dd/Flag_of_Oman.svg'),
#  ('Pakistan', 'Asia', Decimal('881912'), Decimal('188020000'), Decimal('215117000000'), 'Islamabad', '.pk', '//upload.wikimedia.org/wikipedia/commons/3/32/Flag_of_Pakistan.svg'),
#  ('Palau', 'Oceania', Decimal('459'), Decimal('20901'), Decimal('213000000'), 'Ngerulmud', '.pw', '//upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Palau.svg'),
#  ('Panama', 'North America', Decimal('75417'), Decimal('3405813'), Decimal('36253000000'), 'Panama City', '.pa', '//upload.wikimedia.org/wikipedia/commons/a/ab/Flag_of_Panama.svg'),
#  ('Papua New Guinea', 'Oceania', Decimal('462840'), Decimal('7398500'), Decimal('15677000000'), 'Port Moresby', '.pg', '//upload.wikimedia.org/wikipedia/commons/e/e3/Flag_of_Papua_New_Guinea.svg'),
#  ('Paraguay', 'South America', Decimal('406752'), Decimal('6783374'), Decimal('25935000000'), 'Asunción', '.py', '//upload.wikimedia.org/wikipedia/commons/2/27/Flag_of_Paraguay.svg'),
#  ('Peru', 'South America', Decimal('1285216'), Decimal('30475144'), Decimal('204681000000'), 'Lima', '.pe', '//upload.wikimedia.org/wikipedia/commons/c/cf/Flag_of_Peru.svg'),
#  ('Philippines', 'Asia', Decimal('342353'), Decimal('99804200'), Decimal('250182000000'), 'Manila', '.ph', '//upload.wikimedia.org/wikipedia/commons/9/99/Flag_of_the_Philippines.svg'),
#  ('Poland', 'Europe', Decimal('312679'), Decimal('38496000'), Decimal('489852000000'), 'Warsaw', '.pl', '//upload.wikimedia.org/wikipedia/commons/1/12/Flag_of_Poland.svg'),
#  ('Portugal', 'Europe', Decimal('92090'), Decimal('10477800'), Decimal('212139000000'), 'Lisbon', '.pt', '//upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Portugal.svg'),
#  ('Qatar', 'Asia', Decimal('11586'), Decimal('2174035'), Decimal('192402000000'), 'Doha', '.qa', '//upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Qatar.svg'),
#  ('Romania', 'Europe', Decimal('238391'), Decimal('19942642'), Decimal('169396000000'), 'Bucharest', '.ro', '//upload.wikimedia.org/wikipedia/commons/7/73/Flag_of_Romania.svg'),
#  ('Russia', 'Eurasia', Decimal('17125242'), Decimal('146000000'), Decimal('2029812000000'), 'Moscow', '.ru', '//upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Russia.svg'),
#  ('Rwanda', 'Africa', Decimal('26338'), Decimal('10537222'), Decimal('7103000000'), 'Kigali', '.rw', '//upload.wikimedia.org/wikipedia/commons/1/17/Flag_of_Rwanda.svg'),
#  ('Saint Kitts and Nevis', 'North America', Decimal('261'), Decimal('55000'), Decimal('765000000'), 'Basseterre', '.kn', '//upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Saint_Kitts_and_Nevis.svg'),
#  ('Saint Lucia', 'Caribbean', Decimal('616'), Decimal('180000'), Decimal('1318000000'), 'Castries', '.lc', '//upload.wikimedia.org/wikipedia/commons/9/9f/Flag_of_Saint_Lucia.svg'),
#  ('Saint Vincent and the Grenadines', 'South America', Decimal('389'), Decimal('109000'), Decimal('694000000'), 'Kingstown', '.vc', '//upload.wikimedia.org/wikipedia/commons/6/6d/Flag_of_Saint_Vincent_and_the_Grenadines.svg'),
#  ('Samoa', 'Oceania', Decimal('2842'), Decimal('187820'), Decimal('681000000'), 'Apia', '.ws', '//upload.wikimedia.org/wikipedia/commons/3/31/Flag_of_Samoa.svg'),
#  ('San Marino', 'Europe', Decimal('61'), Decimal('32637'), Decimal('1853000000'), 'San Marino', '.sm', '//upload.wikimedia.org/wikipedia/commons/b/b1/Flag_of_San_Marino.svg'),
#  ('Sao Tomé and Príncipe', 'Africa', Decimal('964'), Decimal('190428'), Decimal('707000000'), 'São Tomé', '.st', '//upload.wikimedia.org/wikipedia/commons/4/4f/Flag_of_Sao_Tome_and_Principe.svg'),
#  ('Saudi Arabia', 'Asia', Decimal('2149690'), Decimal('29994272'), Decimal('711050000000'), 'Riyadh', '.sa', '//upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Saudi_Arabia.svg'),
#  ('Senegal', 'Africa', Decimal('196722'), Decimal('12873601'), Decimal('13962000000'), 'Dakar', '.sn', '//upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_Senegal.svg'),
#  ('Serbia', 'Europe', Decimal('88361'), Decimal('7181505'), Decimal('38491000000'), 'Belgrade', '.rs', '//upload.wikimedia.org/wikipedia/commons/6/6d/Flag_of_Serbia_%282004-2010%29.svg'),
#  ('Seychelles', 'Africa', Decimal('452'), Decimal('90945'), Decimal('1031000000'), 'Victoria', '.sc', '//upload.wikimedia.org/wikipedia/commons/f/fc/Flag_of_Seychelles.svg'),
#  ('Sierra Leone', 'Africa', Decimal('71740'), Decimal('6190280'), Decimal('43366000000'), 'Freetown', '.sl', '//upload.wikimedia.org/wikipedia/commons/1/17/Flag_of_Sierra_Leone.svg'),
#  ('Singapore', 'Asia', Decimal('710'), Decimal('5399200'), Decimal('276520000000'), 'Singapore', '.sg', '//upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Singapore.svg'),
#  ('Slovakia', 'Europe', Decimal('49037'), Decimal('5415949'), Decimal('91349000000'), 'Bratislava', '.sk', '//upload.wikimedia.org/wikipedia/commons/e/e6/Flag_of_Slovakia.svg'),
#  ('Slovenia', 'Europe', Decimal('20273'), Decimal('2063151'), Decimal('45380000000'), 'Ljubljana', '.si', '//upload.wikimedia.org/wikipedia/commons/f/f0/Flag_of_Slovenia.svg'),
#  ('Solomon Islands', 'Oceania', Decimal('28896'), Decimal('581344'), Decimal('1010000000'), 'Honiara', '.sb', '//upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_the_Solomon_Islands.svg'),
#  ('Somalia', 'Africa', Decimal('637657'), Decimal('10806000'), Decimal('1306000000'), 'Mogadishu', '.so', '//upload.wikimedia.org/wikipedia/commons/a/a0/Flag_of_Somalia.svg'),
#  ('South Africa', 'Africa', Decimal('1221037'), Decimal('52981991'), Decimal('384313000000'), 'Pretoria', '.za', '//upload.wikimedia.org/wikipedia/commons/a/af/Flag_of_South_Africa.svg'),
#  ('South Korea', 'Asia', Decimal('100210'), Decimal('50423955'), Decimal('1129598000000'), 'Seoul', '.kr', '//upload.wikimedia.org/wikipedia/commons/0/09/Flag_of_South_Korea.svg'),
#  ('South Sudan', 'Africa', Decimal('619745'), Decimal('11739000'), Decimal('10060000000'), 'Juba', '.ss', '//upload.wikimedia.org/wikipedia/commons/7/7a/Flag_of_South_Sudan.svg'),
#  ('Spain', 'Europe', Decimal('505992'), Decimal('46609700'), Decimal('1322126000000'), 'Madrid', '.es', '//upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Spain.svg'),
#  ('Sri Lanka', 'Asia', Decimal('65610'), Decimal('20277597'), Decimal('59421000000'), 'Sri Jayawardenepura Kotte', '.lk', '//upload.wikimedia.org/wikipedia/commons/1/11/Flag_of_Sri_Lanka.svg'),
#  ('Sudan', 'Africa', Decimal('1886068'), Decimal('37289406'), Decimal('51453000000'), 'Khartoum', '.sd', '//upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_Sudan.svg'),
#  ('Suriname', 'South America', Decimal('163820'), Decimal('534189'), Decimal('5012000000'), 'Paramaribo', '.sr', '//upload.wikimedia.org/wikipedia/commons/6/60/Flag_of_Suriname.svg'),
#  ('Swaziland', 'Africa', Decimal('17364'), Decimal('1268000'), Decimal('3861000000'), 'Lobamba', '.sz', '//upload.wikimedia.org/wikipedia/commons/1/1e/Flag_of_Swaziland.svg'),
#  ('Sweden', 'Europe', Decimal('450295'), Decimal('9675885'), Decimal('523804000000'), 'Stockholm', '.se', '//upload.wikimedia.org/wikipedia/commons/4/4c/Flag_of_Sweden.svg'),
#  ('Switzerland', 'Europe', Decimal('41284'), Decimal('8160900'), Decimal('631183000000'), 'Bern', '.ch', '//upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Switzerland.svg'),
#  ('Syria', 'Asia', Decimal('185180'), Decimal('21987000'), Decimal('46540000000'), 'Damascus', '.sy', '//upload.wikimedia.org/wikipedia/commons/5/53/Flag_of_Syria.svg'),
#  ('Taiwan', 'Asia', Decimal('36193'), Decimal('23386883'), None, 'Taipei', '.tw', '//upload.wikimedia.org/wikipedia/commons/7/72/Flag_of_the_Republic_of_China.svg'),
#  ('Tajikistan', 'Asia', Decimal('143100'), Decimal('8160000'), Decimal('7633000000'), 'Dushanbe', '.tj', '//upload.wikimedia.org/wikipedia/commons/d/d0/Flag_of_Tajikistan.svg'),
#  ('Tanzania', 'Africa', Decimal('945087'), Decimal('44928923'), Decimal('28249000000'), 'Dodoma', '.tz', '//upload.wikimedia.org/wikipedia/commons/3/38/Flag_of_Tanzania.svg'),
#  ('Thailand', 'Asia', Decimal('513120'), Decimal('64456700'), Decimal('385694000000'), 'Bangkok', '.th', '//upload.wikimedia.org/wikipedia/commons/a/a9/Flag_of_Thailand.svg'),
#  ('Timor-Leste', 'Asia', Decimal('14874'), Decimal('1212107'), Decimal('5387000000'), 'Dili', '.tl', '//upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_East_Timor.svg'),
#  ('Togo', 'Africa', Decimal('56785'), Decimal('6993000'), Decimal('3917000000'), 'Lomé', '.tg', '//upload.wikimedia.org/wikipedia/commons/9/91/Flag_of_Togo_%281958-1960%29.svg'),
#  ('Tonga', 'Oceania', Decimal('747'), Decimal('103036'), Decimal('465000000'), "Nuku'alofa", '.to', '//upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Tonga.svg'),
#  ('Trinidad and Tobago', 'Caribbean', Decimal('5130'), Decimal('1328019'), Decimal('23225000000'), 'Port of Spain', '.tt', '//upload.wikimedia.org/wikipedia/commons/6/64/Flag_of_Trinidad_and_Tobago.svg'),
#  ('Tunisia', 'Africa', Decimal('163610'), Decimal('10886500'), Decimal('45132000000'), 'Tunis', '.tn', '//upload.wikimedia.org/wikipedia/commons/c/ce/Flag_of_Tunisia.svg'),
#  ('Turkey', 'Asia', Decimal('783562'), Decimal('76667864'), Decimal('788299000000'), 'Ankara', '.tr', '//upload.wikimedia.org/wikipedia/commons/b/b4/Flag_of_Turkey.svg'),
#  ('Turkmenistan', 'Asia', Decimal('488100'), Decimal('5307000'), Decimal('33466000000'), 'Aşgabat', '.tm', '//upload.wikimedia.org/wikipedia/commons/1/1b/Flag_of_Turkmenistan.svg'),
#  ('Tuvalu', 'Oceania', Decimal('26'), Decimal('11323'), Decimal('40000000'), 'Funafuti', '.tv', '//upload.wikimedia.org/wikipedia/commons/3/38/Flag_of_Tuvalu.svg'),
#  ('Uganda', 'Africa', Decimal('241550'), Decimal('35357000'), Decimal('21736000000'), 'Kampala', '.ug', '//upload.wikimedia.org/wikipedia/commons/4/4e/Flag_of_Uganda.svg'),
#  ('Ukraine', 'Europe', Decimal('603500'), Decimal('43009258'), Decimal('176309000000'), 'Kiev', '.ua', '//upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Ukraine.svg'),
#  ('United Arab Emirates', 'Asia', Decimal('83600'), Decimal('9446000'), Decimal('383799000000'), 'Abu Dhabi', '.ae', '//upload.wikimedia.org/wikipedia/commons/c/cb/Flag_of_the_United_Arab_Emirates.svg'),
#  ('United Kingdom', 'Europe', Decimal('242900'), Decimal('64105700'), Decimal('2471600000000'), 'London', '.uk', '//upload.wikimedia.org/wikipedia/commons/a/ae/Flag_of_the_United_Kingdom.svg'),
#  ('United States', 'North America', Decimal('9826675'), Decimal('318320000'), Decimal('16244600000000'), 'Washington, D.C.', '.us', '//upload.wikimedia.org/wikipedia/commons/a/a4/Flag_of_the_United_States.svg'),
#  ('Uruguay', 'South America', Decimal('181034'), Decimal('3286314'), Decimal('49919000000'), 'Montevideo', '.uy', '//upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Uruguay.svg'),
#  ('Uzbekistan', 'Asia', Decimal('447400'), Decimal('30492800'), Decimal('51414000000'), 'Tashkent', '.uz', '//upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Uzbekistan.svg'),
#  ('Vanuatu', 'Oceania', Decimal('12189'), Decimal('264652'), Decimal('752000000'), 'Port Vila', '.vu', '//upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Vanuatu.svg'),
#  ('Vatican City', 'Europe', Decimal('0'), Decimal('839'), None, None, '.va', '//upload.wikimedia.org/wikipedia/commons/0/00/Flag_of_the_Vatican_City.svg'),
#  ('Venezuela', 'South America', Decimal('916445'), Decimal('28946101'), Decimal('382424000000'), 'Caracas', '.ve', '//upload.wikimedia.org/wikipedia/commons/0/06/Flag_of_Venezuela.svg'),
#  ('Vietnam', 'Asia', Decimal('331212'), Decimal('89708900'), Decimal('155820000000'), 'Hanoi', '.vn', '//upload.wikimedia.org/wikipedia/commons/2/21/Flag_of_Vietnam.svg'),
#  ('Yemen', 'Asia', Decimal('527968'), Decimal('25235000'), Decimal('32831000000'), 'Sana‘a', '.ye', '//upload.wikimedia.org/wikipedia/commons/8/89/Flag_of_Yemen.svg'),
#  ('Zambia', 'Africa', Decimal('752612'), Decimal('15023315'), Decimal('21490000000'), 'Lusaka', '.zm', '//upload.wikimedia.org/wikipedia/commons/0/06/Flag_of_Zambia.svg'),
#  ('Zimbabwe', 'Africa', Decimal('390757'), Decimal('13061239'), Decimal('9802000000'), 'Harare', '.zw', '//upload.wikimedia.org/wikipedia/commons/6/6a/Flag_of_Zimbabwe.svg')]

# %% [markdown]
# `world`表一共195行，但由于全局设置了`SqlMagic.displaylimit`，默认只显示了前10行。
